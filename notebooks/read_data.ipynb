# %% [markdown]
# # Test the read_data function

# %%
from re_forecast.data.read_data import read_generation_data
from re_forecast.params import DATA_CSV_ENERGY_PRODUCTION_PATH

# %%
# Set all the params
ressource = 1
start_date = "2024-02-25 00:00:00"
end_date = "2024-02-25 23:00:00"
eic_code = None
prod_type = "WIND_ONSHORE"
prod_subtype = None

generation_data_path = DATA_CSV_ENERGY_PRODUCTION_PATH

# Test the function
read_generation_data(ressource,
                     start_date,
                     end_date,
                     eic_code,
                     prod_type,
                     prod_subtype,
                     generation_data_path)
# Out:
#                     start_date  ... production_type
# 176  2024-02-25T02:00:00+01:00  ...    WIND_ONSHORE
# 177  2024-02-25T03:00:00+01:00  ...    WIND_ONSHORE
# 178  2024-02-25T04:00:00+01:00  ...    WIND_ONSHORE
# 179  2024-02-25T05:00:00+01:00  ...    WIND_ONSHORE
# 180  2024-02-25T06:00:00+01:00  ...    WIND_ONSHORE
# 181  2024-02-25T07:00:00+01:00  ...    WIND_ONSHORE
# 182  2024-02-25T09:00:00+01:00  ...    WIND_ONSHORE
# 183  2024-02-25T10:00:00+01:00  ...    WIND_ONSHORE
# 184  2024-02-25T11:00:00+01:00  ...    WIND_ONSHORE
# 185  2024-02-25T12:00:00+01:00  ...    WIND_ONSHORE
# 186  2024-02-25T13:00:00+01:00  ...    WIND_ONSHORE
# 187  2024-02-25T14:00:00+01:00  ...    WIND_ONSHORE
# 188  2024-02-25T16:00:00+01:00  ...    WIND_ONSHORE
# 189  2024-02-25T17:00:00+01:00  ...    WIND_ONSHORE
# 190  2024-02-25T18:00:00+01:00  ...    WIND_ONSHORE
# 191  2024-02-25T19:00:00+01:00  ...    WIND_ONSHORE
#
# [16 rows x 5 columns]
